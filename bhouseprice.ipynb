# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('C:/Users/NIKITA/OneDrive/Desktop/dsets/HousingData.csv')
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
data.isnull()
# Out:
#       CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD    TAX  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 501  False  False  False  False  False  False  False  False  False  False
# 502  False  False  False  False  False  False  False  False  False  False
# 503  False  False  False  False  False  False  False  False  False  False
# 504  False  False  False  False  False  False  False  False  False  False
# 505  False  False  False  False  False  False   True  False  False  False
#
#      PTRATIO      B  LSTAT   MEDV
# 0      False  False  False  False
# ...

# %%
data.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
data['CRIM'].fillna(value=data['CRIM'].mean(),inplace=True)
data['ZN'].fillna(value=data['ZN'].mean(),inplace=True)
data['INDUS'].fillna(value=data['INDUS'].mean(),inplace=True)
data['CHAS'].fillna(value=data['CHAS'].mean(),inplace=True)
data['AGE'].fillna(value=data['AGE'].mean(),inplace=True)
data['LSTAT'].fillna(value=data['LSTAT'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
fig,ax=plt.subplots(3,4,figsize=(20,20))
ax[0,0].scatter(data['CRIM'],data['MEDV'])
ax[0,1].scatter(data['ZN'],data['MEDV'])
ax[1,0].scatter(data['INDUS'],data['MEDV'])
ax[1,1].scatter(data['CHAS'],data['MEDV'])
ax[0,2].scatter(data['NOX'],data['MEDV'])
ax[1,2].scatter(data['RM'],data['MEDV'])
ax[2,0].scatter(data['AGE'],data['MEDV'])
ax[2,1].scatter(data['DIS'],data['MEDV'])
ax[2,2].scatter(data['RAD'],data['MEDV'])
ax[0,3].scatter(data['TAX'],data['MEDV'])
ax[1,3].scatter(data['PTRATIO'],data['MEDV'])
ax[2,3].scatter(data['B'],data['MEDV'])

# %%
sns.pairplot(data=data,x_vars=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT'],y_vars=['MEDV'])

# %%
plt.scatter(data['RM'],data['MEDV'])

# %%
data.plot(kind='box',subplots=True,layout =(4,4),fontsize=7,figsize=(14,14));

# %%
data['CRIM'].describe()
# Out:
# count    506.000000
# mean       3.611874
# std        8.545770
# min        0.006320
# 25%        0.083235
# 50%        0.290250
# 75%        3.611874
# max       88.976200
# Name: CRIM, dtype: float64

# %%
#data.drop(data[data['CRIM']>2.8].index,axis=0,inplace=True)
#data

# %%
data['ZN'].describe()
# Out:
# count    506.000000
# mean      11.211934
# std       22.921051
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       11.211934
# max      100.000000
# Name: ZN, dtype: float64

# %%
# data.drop(data[data['ZN']>20].index,axis=0,inplace=True)
# data

# %%
data['RM'].describe()
# Out:
# count    506.000000
# mean       6.284634
# std        0.702617
# min        3.561000
# 25%        5.885500
# 50%        6.208500
# 75%        6.623500
# max        8.780000
# Name: RM, dtype: float64

# %%
# data.drop(data[data['RM']>6.7].index,axis=0,inplace=True)
# data

# %%
data['LSTAT'].describe()
# Out:
# count    506.000000
# mean      12.715432
# std        7.012739
# min        1.730000
# 25%        7.230000
# 50%       11.995000
# 75%       16.570000
# max       37.970000
# Name: LSTAT, dtype: float64

# %%
# data.drop(data[data['LSTAT']>13.6].index,axis=0,inplace=True)
# data

# %%
data['MEDV'].describe()
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: MEDV, dtype: float64

# %%
# data.drop(data[data['MEDV']>23.8].index,axis=0,inplace=True)
# data

# %%
plt.figure(figsize = (15,15))
sns.heatmap(data.corr(),annot=True,cmap="Greens")
# Out:
# <AxesSubplot:>

# %%
X=data['RM'].values
Y=data['MEDV'].values
Y[:5]
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2])

# %%
from sklearn.preprocessing import MinMaxScaler
x_scale=MinMaxScaler()
X=x_scale.fit_transform(X.reshape(-1,1))

y_scale=MinMaxScaler()
Y=y_scale.fit_transform(Y.reshape(-1,1))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# array([-0.18137351])

# %%
lr.score(X_test,Y_test)
# Out:
# 0.3118907363305222

# %%
y_pred=lr.predict(X_train)

# %%
plt.scatter(Y_train, y_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %%
X1=data.drop(['MEDV'],axis=1)
Y1=data['MEDV']

# %%
from sklearn.model_selection import train_test_split
X1_train, X1_test, Y1_train, Y1_test = train_test_split(X1,Y1, test_size = 0.3, random_state = 4)

# %%
from sklearn.ensemble import RandomForestRegressor
regr=RandomForestRegressor()
regr.fit(X1_train, Y1_train)
# Out:
# RandomForestRegressor()

# %%
y1_pred=regr.predict(X1_train)

# %%
regr.score(X1_test,Y1_test)
# Out:
# 0.8178423280059262

# %%
plt.scatter(Y1_train, y1_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()
